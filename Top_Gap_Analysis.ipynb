# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
gaps = pd.read_csv('new_gapdata.csv')

# %%
gaps.head()
# normalized_gap = Gap / UnitsRes
# Out:
#    Unnamed: 0  Unnamed: 0.1  ViolationID  BuildingID  RegistrationID  BoroID  \
# 0           0             0     10506902          14          115401       1
# 1           1             1     10506854          14          115401       1
# 2           2             2     10506855          14          115401       1
# 3           3             3     10506853          14          115401       1
# 4           4             4     10604743          14          115401       1
#
#   HouseNumber StreetName  StreetCode    Zip      ...       UnitsRes  \
# 0        1058   1 AVENUE       10010  10022      ...            125
# 1        1058   1 AVENUE       10010  10022      ...            125
# 2        1058   1 AVENUE       10010  10022      ...            125
# 3        1058   1 AVENUE       10010  10022      ...            125
# 4        1058   1 AVENUE       10010  10022      ...            125
#
#   UnitsTotal YearBuilt  XCoord  YCoord Complaints Violations Gap Gap_ratio  \
# 0        132      1929  994719  215676          2          5  -3       -60
# 1        132      1929  994719  215676          2          5  -3       -60
# 2        132      1929  994719  215676          2          5  -3       -60
# 3        132      1929  994719  215676          2          5  -3       -60
# 4        132      1929  994719  215676          2          5  -3       -60
#
#   normalized_gap
# 0         -0.024
# 1         -0.024
# 2         -0.024
# 3         -0.024
# 4         -0.024
#
# [5 rows x 37 columns]

# %%
data = gaps[['BuildingID', 'Full_Address', 'normalized_gap']]
data = data.drop_duplicates()
data = data.replace([np.inf, -np.inf], np.nan) # replace inf with nan
data = data.dropna(subset=['normalized_gap'])
len(data)
# Out:
# 5682

# %%
data.head()
# Out:
#     BuildingID                           Full_Address  normalized_gap
# 0           14       1058 1 AVENUE New York, NY 10022       -0.024000
# 5        30439  253 WEST 15 STREET New York, NY 10011       -0.100000
# 6         6251  431 AUDUBON AVENUE New York, NY 10033       -0.571429
# 31        4885        766 9 AVENUE New York, NY 10019       -2.625000
# 56       13774  152 EAST 46 STREET New York, NY 10017        0.000000

# %%
plt.figure(figsize=(12,10))
plt.hist(data['normalized_gap'], bins=500)
plt.xlim(-4,4)
# Out:
# (-4, 4)

# %%
data['normalized_gap'].describe()
# Out:
# count    5682.000000
# mean       -0.141305
# std         1.304722
# min       -34.000000
# 25%        -0.222222
# 50%         0.000000
# 75%         0.071429
# max        43.500000
# Name: normalized_gap, dtype: float64

# %%
top = data[data['normalized_gap'] < np.mean(data['normalized_gap']) 
                                   - 2*(np.std(data['normalized_gap']))
          ]
print len(top), 'buildings identified'
print len(top)*100.00 / len(data) , ' % of all buildings in population studied' 
top.sort(columns=['normalized_gap'], ascending=True)
# Out:
# 81 buildings identified
# 1.42555438226  % of all buildings in population studied
#        BuildingID                                     Full_Address  \
# 2450        42793           636 WEST 158 STREET New York, NY 10032
# 27190       42968           533 WEST 162 STREET New York, NY 10032
# 5387        42827           538 WEST 159 STREET New York, NY 10032
# 32399        7437                     85 BOWERY New York, NY 10002
# 51951       19175           168 EAST 108 STREET New York, NY 10029
# 33296       11966            444 EAST 13 STREET New York, NY 10009
# 58902       42119           404 WEST 147 STREET New York, NY 10031
# 2069        21308           54 EDGECOMBE AVENUE New York, NY 10030
# 13242        1244                 2242 2 AVENUE New York, NY 10029
# 41559        7435                     83 BOWERY New York, NY 10002
# 6407        42499           508 WEST 151 STREET New York, NY 10031
# 4383        25528        161 MORNINGSIDE AVENUE New York, NY 10027
# 33713        9949            332 CONVENT AVENUE New York, NY 10031
# 28784       43403           558 WEST 181 STREET New York, NY 10033
# 19894       19605           105 EAST 116 STREET New York, NY 10029
# 353         40188            41 WEST 130 STREET New York, NY 10037
# 50432       41118           125 WEST 138 STREET New York, NY 10030
# 9614        43335           534 WEST 178 STREET New York, NY 10033
# 46819       25505              73 MONROE STREET New York, NY 10002
# 1491        38348           240 WEST 116 STREET New York, NY 10026
# 19771       19589           464 EAST 115 STREET New York, NY 10029
# 40182       43523           603 WEST 185 STREET New York, NY 10033
# 5837        33345            412 WEST 46 STREET New York, NY 10036
# 1062        27733              22 SPRING STREET New York, NY 10012
# 21780       24816           2050 MADISON AVENUE New York, NY 10035
# 50817       40445           162 WEST 132 STREET New York, NY 10027
# 11507       43770           172 WEST 225 STREET New York, NY 10463
# 31526        5817         2200 AMSTERDAM AVENUE New York, NY 10032
# 2347        37835           117 WEST 111 STREET New York, NY 10026
# 47082       25948               86 NAGLE AVENUE New York, NY 10040
# ...           ...                                              ...
# 15179       31949            102 WEST 29 STREET New York, NY 10001
# 3772        28932          157 VERMILYEA AVENUE New York, NY 10034
# 40923        1280             2291 1/2 2 AVENUE New York, NY 10035
# 26217       40978           129 WEST 137 STREET New York, NY 10030
# 13561       26990               125 POST AVENUE New York, NY 10034
# 10758       18870           114 EAST 102 STREET New York, NY 10029
# 33125       11177              41 EAST 7 STREET New York, NY 10003
# 20959       21667          133 FT GEORGE AVENUE New York, NY 10040
# 23533       28226        772 ST NICHOLAS AVENUE New York, NY 10031
# 46098       12394            322 EAST 19 STREET New York, NY 10003
# 53117       40379            72 WEST 131 STREET New York, NY 10037
# 26957       42449           521 WEST 150 STREET New York, NY 10031
# 17210        6340                  196 AVENUE A New York, NY 10009
# 58520       13944            302 EAST 49 STREET New York, NY 10017
# 33878       14668            210 EAST 60 STREET New York, NY 10022
# 27759       43109           503 WEST 169 STREET New York, NY 10032
# 39986       43219           513 WEST 173 STREET New York, NY 10032
# 818         24438              53 LUDLOW STREET New York, NY 10002
# 51528        3545  2309 ADAM C POWELL BOULEVARD New York, NY 10030
# 4930         5951          488 AMSTERDAM AVENUE New York, NY 10024
# 47519       29352         16 WASHINGTON TERRACE New York, NY 10033
# 50944       41848           474 WEST 144 STREET New York, NY 10031
# 31059        6187            171 AUDUBON AVENUE New York, NY 10033
# 34647       19098           159 EAST 106 STREET New York, NY 10029
# 26777       39831           366 WEST 127 STREET New York, NY 10027
# 45292        5314                 735 11 AVENUE New York, NY 10019
# 54246       19289           158 EAST 110 STREET New York, NY 10029
# 48586        1376                  316 2 AVENUE New York, NY 10003
# 22769       27605             25 SHERMAN AVENUE New York, NY 10040
# 28293       42809           509 WEST 159 STREET New York, NY 10032
#
#        normalized_gap
# 2450       -34.000000
# 27190      -15.500000
# 5387       -12.200000
# 32399      -12.187500
# 51951      -10.200000
# 33296       -9.866667
# 58902       -9.666667
# 2069        -9.000000
# 13242       -9.000000
# 41559       -8.333333
# 6407        -8.142857
# 4383        -7.700000
# 33713       -6.875000
# 28784       -6.692308
# 19894       -6.625000
# 353         -6.600000
# 50432       -6.200000
# 9614        -6.095238
# 46819       -5.875000
# 1491        -5.833333
# 19771       -5.750000
# 40182       -5.600000
# 5837        -5.187500
# 1062        -5.125000
# 21780       -5.000000
# 50817       -5.000000
# 11507       -5.000000
# 31526       -4.960000
# 2347        -4.888889
# 47082       -4.800000
# ...               ...
# 15179       -4.000000
# 3772        -3.838710
# 40923       -3.818182
# 26217       -3.800000
# 13561       -3.800000
# 10758       -3.777778
# 33125       -3.681818
# 20959       -3.675000
# 23533       -3.660714
# 46098       -3.600000
# 53117       -3.500000
# 26957       -3.363636
# 17210       -3.333333
# 58520       -3.333333
# 33878       -3.333333
# 27759       -3.291667
# 39986       -3.250000
# 818         -3.250000
# 51528       -3.000000
# 4930        -3.000000
# 47519       -3.000000
# 50944       -3.000000
# 31059       -2.950000
# 34647       -2.875000
# 26777       -2.875000
# 45292       -2.857143
# 54246       -2.833333
# 48586       -2.800000
# 22769       -2.790698
# 28293       -2.772727
#
# [81 rows x 3 columns]

# %%
top.sort(columns=['normalized_gap'], ascending=True).to_csv('top_gap_bldgs_2SD.csv')
