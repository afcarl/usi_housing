# %%
import pandas as pd

# %%
gaps = pd.read_csv('new_gapdata.csv')
gaps.dtypes
# Out:
# Unnamed: 0                 int64
# ViolationID                int64
# BuildingID                 int64
# RegistrationID             int64
# BoroID                     int64
# HouseNumber               object
# StreetName                object
# StreetCode                 int64
# Zip                        int64
# Apartment                 object
# Story                     object
# Class                     object
# InspectionDate            object
# ApprovedDate              object
# OriginalCertifyByDate     object
# OriginalCorrectByDate     object
# NewCertifyByDate          object
# NewCorrectByDate          object
# CertifiedDate             object
# OrderNumber                int64
# CurrentStatusID            int64
# CurrentStatus             object
# CurrentStatusDate         object
# BBL                        int64
# Full_Address              object
# Address                   object
# UnitsRes                   int64
# UnitsTotal                 int64
# ...

# %%
gaps.head()
# Out:
#    Unnamed: 0  ViolationID  BuildingID  RegistrationID  BoroID HouseNumber  \
# 0           0     10506902          14          115401       1        1058
# 1           1     10506854          14          115401       1        1058
# 2           2     10506855          14          115401       1        1058
# 3           3     10506853          14          115401       1        1058
# 4           4     10604743          14          115401       1        1058
#
#   StreetName  StreetCode    Zip Apartment          ...          UnitsRes  \
# 0   1 AVENUE       10010  10022     PENTC          ...               125
# 1   1 AVENUE       10010  10022     PENTC          ...               125
# 2   1 AVENUE       10010  10022     PENTC          ...               125
# 3   1 AVENUE       10010  10022     PENTC          ...               125
# 4   1 AVENUE       10010  10022       PHC          ...               125
#
# ...
